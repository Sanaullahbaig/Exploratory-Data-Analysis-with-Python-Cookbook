# %% [markdown]
# Import relevant libraries

# %%
import pandas as pd

# %% [markdown]
# Load dataset

# %%
marketing_data = pd.read_csv("marketing_campaign.csv")

# %% [markdown]
# Subset for relevant columns

# %%
marketing_data = marketing_data[['ID', 'Year_Birth', 'Education','Income']]

# %% [markdown]
# Inspect first 5 rows and data types of the dataset

# %%
marketing_data.head()
# Out:
#      ID  Year_Birth   Education   Income
# 0  5524        1957  Graduation  58138.0
# 1  2174        1954  Graduation  46344.0
# 2  4141        1965  Graduation  71613.0
# 3  6182        1984  Graduation  26646.0
# 4  5324        1981         PhD  58293.0

# %%
marketing_data.shape
# Out:
# (2240, 4)

# %% [markdown]
# Check for missing values

# %%
# isnull count the NaN values in data and then show their sum means number of NaN values
marketing_data.isnull().sum()
# Out:
# ID             0
# Year_Birth     0
# Education      0
# Income        24
# dtype: int64

# %% [markdown]
# Drop Missing values

# %%
# dropna will remove the rows with NaN values
marketing_data_withoutna = marketing_data.dropna(how = 'any')
marketing_data_withoutna.head()
# Out:
#      ID  Year_Birth   Education   Income
# 0  5524        1957  Graduation  58138.0
# 1  2174        1954  Graduation  46344.0
# 2  4141        1965  Graduation  71613.0
# 3  6182        1984  Graduation  26646.0
# 4  5324        1981         PhD  58293.0

# %%
marketing_data_withoutna.shape
# Out:
# (2216, 4)
