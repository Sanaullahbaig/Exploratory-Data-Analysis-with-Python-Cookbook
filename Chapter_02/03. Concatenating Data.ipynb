# %% [markdown]
# Import relevant libraries

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# Load datasets

# %%
marketing_sample1 = pd.read_csv("marketing_campaign_concat1.csv")
marketing_sample2 = pd.read_csv("marketing_campaign_concat2.csv")

# %% [markdown]
# Inspect the datasets

# %%
marketing_sample1.shape
# Out:
# (2240, 5)

# %%
marketing_sample1.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income
# 0  5524        1957  Graduation         Single  58138.0
# 1  2174        1954  Graduation         Single  46344.0
# 2  4141        1965  Graduation       Together  71613.0
# 3  6182        1984  Graduation       Together  26646.0
# 4  5324        1981         PhD        Married  58293.0

# %%
marketing_sample2.shape
# Out:
# (2240, 5)

# %%
marketing_sample2.head()
# Out:
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                  3                8                   10                  4
# 1                  2                1                    1                  2
# 2                  1                8                    2                 10
# 3                  2                2                    0                  4
# 4                  5                5                    3                  6
#
#    NumWebVisitsMonth
# 0                  7
# 1                  5
# 2                  4
# 3                  6
# 4                  5

# %% [markdown]
# Concatenate(combine) the two datasets into one new dataset

# %%
concatenated_data = pd.concat([marketing_sample1, marketing_sample2], axis = 1)
# axis = 1, it will combine column wise axis = 0 it will combine row wise

# %%
concatenated_data.shape
# Out:
# (2240, 10)

# %%
concatenated_data.head()
# Out:
#      ID  Year_Birth   Education Marital_Status   Income  NumDealsPurchases  \
# 0  5524        1957  Graduation         Single  58138.0                  3
# 1  2174        1954  Graduation         Single  46344.0                  2
# 2  4141        1965  Graduation       Together  71613.0                  1
# 3  6182        1984  Graduation       Together  26646.0                  2
# 4  5324        1981         PhD        Married  58293.0                  5
#
#    NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth
# 0                8                   10                  4                  7
# 1                1                    1                  2                  5
# 2                8                    2                 10                  4
# 3                2                    0                  4                  6
# 4                5                    3                  6                  5

# %%
# axis = 0 it will combine row wise 
concatenated_data = pd.concat([marketing_sample1, marketing_sample2], axis = 0)
concatenated_data.head()
# Out:
#        ID  Year_Birth   Education Marital_Status   Income  NumDealsPurchases  \
# 0  5524.0      1957.0  Graduation         Single  58138.0                NaN
# 1  2174.0      1954.0  Graduation         Single  46344.0                NaN
# 2  4141.0      1965.0  Graduation       Together  71613.0                NaN
# 3  6182.0      1984.0  Graduation       Together  26646.0                NaN
# 4  5324.0      1981.0         PhD        Married  58293.0                NaN
#
#    NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth
# 0              NaN                  NaN                NaN                NaN
# 1              NaN                  NaN                NaN                NaN
# 2              NaN                  NaN                NaN                NaN
# 3              NaN                  NaN                NaN                NaN
# 4              NaN                  NaN                NaN                NaN
